# %%
import numpy as np

# %%
x = np.array([1,2,3,4,5]) +.0
y = np.array([2,4,6,8,10]) +.0
w = np.random.rand()
b = np.random.rand()
lr = 0.01
for i in range(20):
    y_pred = (x*w) + b
    err = (y_pred - y) 
    w -= lr * ((x * err).sum() / len(x) )
    b -= lr * ((err).sum() / len(x) )
    print(f'Epoch {i}, pred: {y_pred[1]-y_pred[0]}, Error {(err ** 2).mean()}')
# Out:
# Epoch 0, pred: 0.8230875592951177, Error 10.370447166110093
# Epoch 1, pred: 0.9293311963372166, Error 8.103399733290578
# Epoch 2, pred: 1.0230609794224046, Error 6.340906029201474
# Epoch 3, pred: 1.105757322298103, Error 4.970641821501081
# Epoch 4, pred: 1.1787254918328327, Error 3.905288709770774
# Epoch 5, pred: 1.2431163295589354, Error 3.076967279816077
# Epoch 6, pred: 1.299944521659539, Error 2.4329095597098456
# Epoch 7, pred: 1.3501047074421586, Error 1.93209488187451
# Epoch 8, pred: 1.394385682026532, Error 1.5426346759246754
# Epoch 9, pred: 1.4334829187192915, Error 1.239739463884538
# Epoch 10, pred: 1.4680096098725155, Error 1.0041384467837897
# Epoch 11, pred: 1.498506401503608, Error 0.8208509258813924
# Epoch 12, pred: 1.5254499762169953, Error 0.6782312324254158
# Epoch 13, pred: 1.5492606206844752, Error 0.5672262769601902
# Epoch 14, pred: 1.5703088978206141, Error 0.48079838441407396
# Epoch 15, pred: 1.5889215295762797, Error 0.4134766187340536
# Epoch 16, pred: 1.605386583741701, Error 0.3610079924807038
# Epoch 17, pred: 1.619958047101357, Error 0.32008632480425714
# Epoch 18, pred: 1.632859857541106, Error 0.28814146157202236
# Epoch 19, pred: 1.6442894591186645, Error 0.26317541971056757

# %%
m = 100  # Number of samples
n = 2    # Number of features
X = np.random.rand(m, n)
y = 3 * X[:, 0] + 5 * X[:, 1] + 2 + 0.1 * np.random.randn(m)  # True coefficients: [3, 5], Intercept: 2
x1 = X[:,0]
x2 = X[:,1]
#chat gpt data set

# %%
lr = 0.01
b = np.random.rand()
w1 = np.random.rand()
w2 = np.random.rand()

# Gradient Descent or Batch Gradient Descent or Vanilla Gradient Descent
for epoch in range(20):
    y_p = ((x1* w1) + (x2 * w2)) +  b

    err = y_p - y

    w1 -= lr * ((x1 * err).sum() / len(x1)) 
    w2 -= lr * ((x2 * err).sum() / len(x2)) 
    b -= lr * (err.sum() / len(err))

    print(f'Epoch {epoch}, Cost: {np.mean(err ** 2)}')
# Out:
# Epoch 0, Cost: 29.686588128615817
# Epoch 1, Cost: 28.80665506786975
# Epoch 2, Cost: 27.953539950540257
# Epoch 3, Cost: 27.12642443622383
# Epoch 4, Cost: 26.324515157245674
# Epoch 5, Cost: 25.5470429565824
# Epoch 6, Cost: 24.793262149040512
# Epoch 7, Cost: 24.062449804981075
# Epoch 8, Cost: 23.353905055902583
# Epoch 9, Cost: 22.66694842121478
# Epoch 10, Cost: 22.000921155557066
# Epoch 11, Cost: 21.355184616034308
# Epoch 12, Cost: 20.72911964876231
# Epoch 13, Cost: 20.122125994133764
# Epoch 14, Cost: 19.533621710233266
# Epoch 15, Cost: 18.963042613847662
# Epoch 16, Cost: 18.40984173853474
# Epoch 17, Cost: 17.873488809229677
# Epoch 18, Cost: 17.353469732884633
# Epoch 19, Cost: 16.849286104652137

# %%
# Stochastic Gradient Descent
b = 0.2#np.random.rand()
w1 = 0.043#np.random.rand()
w2 = 0.612#np.random.rand()

# calculate gradient for 1 sample
for epoch in range(20):

    y_p = ((x1* w1) + (x2 * w2)) +  b

    ind = np.random.choice(X.shape[0],1,replace=False)[0]
    err = y_p[ind] - y[ind]

    w1 -= lr * ((x1[ind] * err)) 
    w2 -= lr * ((x2[ind] * err))

    b -= lr * (err)

    print(f'Epoch {epoch}, Cost: {np.mean(err ** 2)}')
# Out:
# Epoch 0, Cost: 24.93629763653763
# Epoch 1, Cost: 46.64247451908338
# Epoch 2, Cost: 22.842560944905365
# Epoch 3, Cost: 22.202788619951104
# Epoch 4, Cost: 9.081080813785299
# Epoch 5, Cost: 42.27509885945288
# Epoch 6, Cost: 8.385704544375093
# Epoch 7, Cost: 22.852495283254406
# Epoch 8, Cost: 35.630977274856285
# Epoch 9, Cost: 55.27404408878551
# Epoch 10, Cost: 25.883088865971576
# Epoch 11, Cost: 19.13064508479908
# Epoch 12, Cost: 11.981599576279358
# Epoch 13, Cost: 14.584258170047608
# Epoch 14, Cost: 34.569256542798676
# Epoch 15, Cost: 20.786723545664422
# Epoch 16, Cost: 43.03016405282362
# Epoch 17, Cost: 1.2934847332908992
# Epoch 18, Cost: 27.76540786950175
# Epoch 19, Cost: 14.84777442831766

# %%
# mini batch
batch = 12
b = 0.2#np.random.rand()
w1 = 0.043#np.random.rand()
w2 = 0.612#np.random.rand()

# calculate gradient for random subset of array
for epoch in range(20):

    y_p = ((x1* w1) + (x2 * w2)) +  b

    ind = np.random.choice(X.shape[0], batch,replace=False)
    
    err = y_p[ind] - y[ind]

    w1 -= lr * ((x1[ind] * err).sum() / batch) 
    w2 -= lr * ((x2[ind] * err).sum() / batch)

    b -= lr * (err.sum() / batch)

    print(f'Epoch {epoch}, Cost: {np.mean(err ** 2)}')
# Out:
# Epoch 0, Cost: 31.248225730522567
# Epoch 1, Cost: 30.95181415211906
# Epoch 2, Cost: 36.42597142213932
# Epoch 3, Cost: 29.93742048110101
# Epoch 4, Cost: 26.991998529587974
# Epoch 5, Cost: 26.938923941550502
# Epoch 6, Cost: 35.201087278800564
# Epoch 7, Cost: 32.011719818582755
# Epoch 8, Cost: 23.20651851216761
# Epoch 9, Cost: 29.919181427370678
# Epoch 10, Cost: 21.432146004395552
# Epoch 11, Cost: 17.80162050185444
# Epoch 12, Cost: 22.678437162355312
# Epoch 13, Cost: 21.344715194390034
# Epoch 14, Cost: 25.835149839926242
# Epoch 15, Cost: 23.252815781118343
# Epoch 16, Cost: 20.218439353895803
# Epoch 17, Cost: 21.12052099792393
# Epoch 18, Cost: 22.630332103371703
# Epoch 19, Cost: 23.75840171371699

# %%
# momntum with stochastic Gradient Descent
# Method 1
vw1,vw2,vb = 0,0,0 # initial value for momentum
momentum_hyperparameter = 0.98

b = 0.2#np.random.rand()
w1 = 0.043#np.random.rand()
w2 = 0.612#np.random.rand()

# calculate gradient for 1 sample
for epoch in range(20):

    y_p = ((x1* w1) + (x2 * w2)) +  b

    ind = np.random.choice(X.shape[0],1,replace=False)[0]

    err = y_p[ind] - y[ind]

    vw1 = (momentum_hyperparameter * vw1) + ((1 - momentum_hyperparameter) * ((x1[ind] * err)))
    vw2 = (momentum_hyperparameter * vw2) + ((1 - momentum_hyperparameter) * ((x2[ind] * err)))

    vb = (momentum_hyperparameter * vb) + ((1 - momentum_hyperparameter) * (err))

    w1 -= lr * vw1
    w2 -= lr * vw2

    b -= lr * vb

    print(f'Epoch {epoch}, Cost: {np.mean(err ** 2)}')
# Out:
# Epoch 0, Cost: 32.838522053632595
# Epoch 1, Cost: 50.675705477710125
# Epoch 2, Cost: 22.808010678491225
# Epoch 3, Cost: 45.18828364189596
# Epoch 4, Cost: 15.092278770637476
# Epoch 5, Cost: 27.415819843092518
# Epoch 6, Cost: 29.28644578709473
# Epoch 7, Cost: 24.32151656881525
# Epoch 8, Cost: 68.17845969862134
# Epoch 9, Cost: 67.85508935979875
# Epoch 10, Cost: 31.69825387250191
# Epoch 11, Cost: 46.06676853872257
# Epoch 12, Cost: 31.493529827690548
# Epoch 13, Cost: 8.879934395356905
# Epoch 14, Cost: 30.981963872943858
# Epoch 15, Cost: 4.689201079696532
# Epoch 16, Cost: 3.343318425658748
# Epoch 17, Cost: 12.43339007215673
# Epoch 18, Cost: 8.912032686093278
# Epoch 19, Cost: 26.598602775321613

# %%
# momntum with stochastic Gradient Descent
# Method 2
vw1,vw2,vb = 0,0,0 # initial value for momentum
momentum_hyperparameter = 0.98

b = 0.2#np.random.rand()
w1 = 0.043#np.random.rand()
w2 = 0.612#np.random.rand()

# calculate gradient for 1 sample
for epoch in range(20):

    y_p = ((x1* w1) + (x2 * w2)) +  b

    ind = np.random.choice(X.shape[0],1,replace=False)[0]

    err = y_p[ind] - y[ind]

    vw1 = (momentum_hyperparameter * vw1) +( lr * ((x1[ind] * err)))
    vw2 = (momentum_hyperparameter * vw2) + (lr * ((x2[ind] * err)))

    vb = (momentum_hyperparameter * vb) + (lr * (err))

    w1 -=  vw1
    w2 -=  vw2

    b -=  vb

    print(f'Epoch {epoch}, Cost: {np.mean(err ** 2)}')
# Out:
# Epoch 0, Cost: 32.021624321661484
# Epoch 1, Cost: 61.131342545777144
# Epoch 2, Cost: 19.992823655521132
# Epoch 3, Cost: 64.63104927451212
# Epoch 4, Cost: 20.361123210617304
# Epoch 5, Cost: 10.259690935507498
# Epoch 6, Cost: 15.700704615296374
# Epoch 7, Cost: 4.59531386910751
# Epoch 8, Cost: 10.601440611781316
# Epoch 9, Cost: 7.525790616228168
# Epoch 10, Cost: 0.08828269469685861
# Epoch 11, Cost: 0.4540575318281856
# Epoch 12, Cost: 0.07954255608177226
# Epoch 13, Cost: 2.891567461162496
# Epoch 14, Cost: 2.8758474059793238
# Epoch 15, Cost: 2.4838796093598834
# Epoch 16, Cost: 5.426167094830874
# Epoch 17, Cost: 8.566144186970144
# Epoch 18, Cost: 14.202014117971112
# Epoch 19, Cost: 13.428689652925097

# %%
# momntum with mini batch
# Method 1
vw1,vw2,vb = 0,0,0 # initial value for momentum
momentum_hyperparameter = 0.98

batch = 12
b = 0.2#np.random.rand()
w1 = 0.043#np.random.rand()
w2 = 0.612#np.random.rand()

# calculate gradient for random subset of array
for epoch in range(20):

    y_p = ((x1* w1) + (x2 * w2)) +  b

    ind = np.random.choice(X.shape[0], batch,replace=False)
    
    err = y_p[ind] - y[ind]

    vw1 = (momentum_hyperparameter * vw1) + ((1 - momentum_hyperparameter) * ((x1[ind] * err).sum() / batch)) 
    vw2 = (momentum_hyperparameter * vw2) + ((1 - momentum_hyperparameter) * ((x2[ind] * err).sum() / batch))

    vb = (momentum_hyperparameter * vb) + ((1 - momentum_hyperparameter) * (err.sum() / batch))

    w1 -= lr * vw1
    w2 -= lr * vw2

    b -= lr * vb

    print(f'Epoch {epoch}, Cost: {np.mean(err ** 2)}')
# Out:
# Epoch 0, Cost: 35.262570751053055
# Epoch 1, Cost: 30.478456687286783
# Epoch 2, Cost: 33.88483278600167
# Epoch 3, Cost: 39.623791037075996
# Epoch 4, Cost: 35.73362380021928
# Epoch 5, Cost: 37.74762324436168
# Epoch 6, Cost: 36.96776654322543
# Epoch 7, Cost: 17.18332063576084
# Epoch 8, Cost: 28.014703800248338
# Epoch 9, Cost: 34.3246173134122
# Epoch 10, Cost: 44.181407991948326
# Epoch 11, Cost: 21.774917924627434
# Epoch 12, Cost: 32.297847654872385
# Epoch 13, Cost: 34.50407938317572
# Epoch 14, Cost: 25.560364318280744
# Epoch 15, Cost: 33.39559333789418
# Epoch 16, Cost: 27.807009496482348
# Epoch 17, Cost: 28.65505038976261
# Epoch 18, Cost: 34.2524287352703
# Epoch 19, Cost: 38.40607344123749

# %%
# momntum with mini batch
# Method 2

vw1,vw2,vb = 0,0,0 # initial value for momentum
momentum_hyperparameter = 0.98

batch = 12
b = 0.2#np.random.rand()
w1 = 0.043#np.random.rand()
w2 = 0.612#np.random.rand()

# calculate gradient for random subset of array
for epoch in range(20):

    y_p = ((x1* w1) + (x2 * w2)) +  b

    ind = np.random.choice(X.shape[0], batch,replace=False)
    
    err = y_p[ind] - y[ind]

    vw1 = (momentum_hyperparameter * vw1) + (lr * ((x1[ind] * err).sum() / batch)) 
    vw2 = (momentum_hyperparameter * vw2) + (lr * ((x2[ind] * err).sum() / batch))

    vb = (momentum_hyperparameter * vb) + (lr * (err.sum() / batch))

    w1 -= vw1
    w2 -= vw2

    b -= vb

    print(f'Epoch {epoch}, Cost: {np.mean(err ** 2)}')
# Out:
# Epoch 0, Cost: 24.439880101394124
# Epoch 1, Cost: 36.12977911714034
# Epoch 2, Cost: 23.396029073942184
# Epoch 3, Cost: 24.36358555895544
# Epoch 4, Cost: 24.07075739106224
# Epoch 5, Cost: 19.118498888360335
# Epoch 6, Cost: 16.085537088737997
# Epoch 7, Cost: 11.610216446090902
# Epoch 8, Cost: 9.04199381104329
# Epoch 9, Cost: 8.582173950647753
# Epoch 10, Cost: 5.32837803113225
# Epoch 11, Cost: 2.438306207111307
# Epoch 12, Cost: 1.3217973127274127
# Epoch 13, Cost: 0.5090413347303527
# Epoch 14, Cost: 0.5927900823350923
# Epoch 15, Cost: 1.4995009723816655
# Epoch 16, Cost: 2.65399020883644
# Epoch 17, Cost: 4.449410524232042
# Epoch 18, Cost: 7.871822023226199
# Epoch 19, Cost: 8.374462228609223
